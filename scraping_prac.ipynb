# %%
import pandas as pd
from selenium import webdriver
import yfinance
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time

# %%
# ヘッドレスモードに設定
options = Options()
options.add_argument('--headless')

# %%
browser = webdriver.Chrome(options=options)
url = 'https://doda.jp/dcfront/login/login/'
browser.get(url)

# %%
elem_mail = browser.find_element(By.ID, 'mailAddress')
elem_mail.send_keys("Selenium")
# elem_mail.send_keys(Keys.ENTER)

elem_agree = browser.find_element(By.NAME, 'doLogin')
time.sleep(3)
elem_agree.click()

# %%
name = elem_agree.text

# %%
elems_th = browser.find_elements(By.ID)

# %%
url = 'https://www.wantedly.com/projects?new=true&page=1&occupationTypes=jp__engineering&hiringTypes=mid_career&order=mixed'
browser = webdriver.Chrome()
browser.get(url)

# %%
page = browser.find_elements(By.TAG_NAME, 'span')

# %%
for i in range(len(page)):
    texts = page[i].text
    print(texts)
# Out:
# 2
# バックエンドエンジニア・中途
# フロントエンドエンジニア・中途
# Webエンジニア・中途
# サーバーサイドエンジニア・中途
# iOSアプリエンジニア・中途
# NEW
# Webエンジニア・中途
# Full-Stack・中途
# SRE/システム運用エンジニア・中途
# フロントエンド│フルリモート・中途
# モバイルエンジニア・中途
# 推奨環境
# ヘルプ
# 利用規約
# プライバシ
# ー
# ポリシ
# ー
# 利用者情報の外部送信について
# 販売
# ・
# 運用代行プログラム
# ©2024 Wantedly, Inc.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.wantedly.com/projects/1146398?featured=0'
res = requests.get(url)

# %%
res.text
# Out:
# '<!DOCTYPE html><html lang="ja"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, minimum-scale=1, maximum-scale=1, initial-scale=1, viewport-cover=cover, user-scalable=no"/><meta property="fb:app_id" content="234170156611754"/><meta property="og:title" content="観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？ - 株式会社ネクストビートの法人営業の採用 - Wantedly"/><title>観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？ - 株式会社ネクストビートの法人営業の採用 - Wantedly</title><meta name="keywords" content="株式会社ネクストビート,求人,転職,募集,採用"/><meta property="description" content="株式会社ネクストビートの法人営業の転職・採用情報。Wantedlyでは、働くモチベーションや一緒に働くメンバーについて知ることができます。■業務内容 コンサルティング営業職 宿泊施設の経営も一般的な企業の経営同様にマーケティング、数値をもとにした採用計画を実行しており、多くの..."/><meta property="og:type" content="article"/><meta property="og:description" content="■業務内容 コンサルティング営業職 宿泊施設の経営も一般的な企業の経営同様にマーケティング、数値をもとにした採用計画を実行しており、多くの..."/><meta property="og:url" content="https://www.wantedly.com/projects/1146398"/><meta property="og:image" content="https://images.wantedly.com/i/x3RxxQt?w=1200&amp;h=630"/><meta property="og:image:width" content="1200"/><meta property="og:image:height" content="630"/><meta property="twitter:card" content="summary_large_image"/><meta property="twitter:site" content="@wantedly"/><meta property="twitter:url" content="https://www.wantedly.com/projects/1146398"/><meta property="twitter:title" content="観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？ by 株式会社ネクストビート"/><meta property="twitter:description" content="■業務内容 コンサルティング営業職 宿泊施設の経営も一般的な企業の経営同様にマーケティング、数値をもとにした採用計画を実行しており、多くの..."/><meta property="twitter:image" content="https://images.wantedly.com/i/x3RxxQt?w=1200&amp;h=630"/><link rel="canonical" href="https://www.wantedly.com/projects/1146398"/><link rel="alternative" hrefLang="x-default" href="https://www.wantedly.com/projects/1146398"/><link rel="alternative" hrefLang="ja" href="https://www.wantedly.com/projects/1146398"/><link rel="alternative" hrefLang="en" href="https://sg.wantedly.com/projects/1146398"/><link rel="alternative" hrefLang="ja-jp" href="https://www.wantedly.com/projects/1146398"/><link rel="alternative" hrefLang="en-jp" href="https://en-jp.wantedly.com/projects/1146398"/><link rel="alternative" hrefLang="en-sg" href="https://sg.wantedly.com/projects/1146398"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Wantedly","item":"https://www.wantedly.com/projects"},{"@type":"ListItem","position":2,"name":"セールス・事業開発 中途の募集","item":"https://www.wantedly.com/project_categories/sales/mid_career"},{"@type":"ListItem","position":3,"name":"観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？","item":"https://www.wantedly.com/projects/1146398"}]}</script><meta name="next-head-count" content="27"/><link rel="shortcut icon" href="/favicon.ico"/><style type="text/css">$.fresnel-container{margin:0;padding:0;}\n@media not all and (min-width:0px) and (max-width:560.98px){.fresnel-at-mobile{display:none!important;}}\n@media not all and (min-width:561px) and (max-width:960.98px){.fresnel-at-tablet{display:none!important;}}\n@media not all and (min-width:961px) and (max-width:1280.98px){.fresnel-at-laptop{display:none!important;}}\n@media not all and (min-width:1281px) and (max-width:1680.98px){.fresnel-at-laptopL{display:none!important;}}\n@media not all and (min-width:1681px) and (max-width:1920.98px){.fresnel-at-laptopLL{display:none!important;}}\n@media not all and (min-width:1921px){.fresnel-at-laptopXL{display:none!important;}}\n@media not all and (max-width:560.98px){.fresnel-lessThan-tablet{display:none!important;}}\n@media not all and (max-width:960.98px){.fresnel-lessThan-laptop{display:none!important;}}\n@media not all and (max-width:1280.98px){.fresnel-lessThan-laptopL{display:none!important;}}\n@media not all and (max-width:1680.98px){.fresnel-lessThan-laptopLL{display:none!important;}}\n@media not all and (max-width:1920.98px){.fresnel-lessThan-laptopXL{display:none!important;}}\n@media not all and (min-width:561px){ ...

# %%
# htmlとして読み込んで構造を解析してくれる
soup = BeautifulSoup(res.text, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="ja">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, minimum-scale=1, maximum-scale=1, initial-scale=1, viewport-cover=cover, user-scalable=no" name="viewport"/>\n  <meta content="234170156611754" property="fb:app_id"/>\n  <meta content="観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？ - 株式会社ネクストビートの法人営業の採用 - Wantedly" property="og:title"/>\n  <title>\n   観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？ - 株式会社ネクストビートの法人営業の採用 - Wantedly\n  </title>\n  <meta content="株式会社ネクストビート,求人,転職,募集,採用" name="keywords"/>\n  <meta content="株式会社ネクストビートの法人営業の転職・採用情報。Wantedlyでは、働くモチベーションや一緒に働くメンバーについて知ることができます。■業務内容 コンサルティング営業職 宿泊施設の経営も一般的な企業の経営同様にマーケティング、数値をもとにした採用計画を実行しており、多くの..." property="description"/>\n  <meta content="article" property="og:type"/>\n  <meta content="■業務内容 コンサルティング営業職 宿泊施設の経営も一般的な企業の経営同様にマーケティング、数値をもとにした採用計画を実行しており、多くの..." property="og:description"/>\n  <meta content="https://www.wantedly.com/projects/1146398" property="og:url"/>\n  <meta content="https://images.wantedly.com/i/x3RxxQt?w=1200&amp;h=630" property="og:image"/>\n  <meta content="1200" property="og:image:width"/>\n  <meta content="630" property="og:image:height"/>\n  <meta content="summary_large_image" property="twitter:card"/>\n  <meta content="@wantedly" property="twitter:site"/>\n  <meta content="https://www.wantedly.com/projects/1146398" property="twitter:url"/>\n  <meta content="観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？ by 株式会社ネクストビート" property="twitter:title"/>\n  <meta content="■業務内容 コンサルティング営業職 宿泊施設の経営も一般的な企業の経営同様にマーケティング、数値をもとにした採用計画を実行しており、多くの..." property="twitter:description"/>\n  <meta content="https://images.wantedly.com/i/x3RxxQt?w=1200&amp;h=630" property="twitter:image"/>\n  <link href="https://www.wantedly.com/projects/1146398" rel="canonical"/>\n  <link href="https://www.wantedly.com/projects/1146398" hreflang="x-default" rel="alternative"/>\n  <link href="https://www.wantedly.com/projects/1146398" hreflang="ja" rel="alternative"/>\n  <link href="https://sg.wantedly.com/projects/1146398" hreflang="en" rel="alternative"/>\n  <link href="https://www.wantedly.com/projects/1146398" hreflang="ja-jp" rel="alternative"/>\n  <link href="https://en-jp.wantedly.com/projects/1146398" hreflang="en-jp" rel="alternative"/>\n  <link href="https://sg.wantedly.com/projects/1146398" hreflang="en-sg" rel="alternative"/>\n  <script type="application/ld+json">\n   {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Wantedly","item":"https://www.wantedly.com/projects"},{"@type":"ListItem","position":2,"name":"セールス・事業開発 中途の募集","item":"https://www.wantedly.com/project_categories/sales/mid_career"},{"@type":"ListItem","position":3,"name":"観光業界から地方創生を実現！200％成長の新規事業を加速させませんか？","item":"https://www.wantedly.com/projects/1146398"}]}\n  </script>\n  <meta content="27" name="next-head-count"/>\n  <link href="/favicon.ico" rel="shortcut icon"/>\n  <style type="text/css">\n   $.fresnel-container{margin:0;padding:0;}\n@media not all and (min-width:0px) and (max-width:560.98px){.fresnel-at-mobile{display:none!important;}}\n@media not all and (min-width:561px) and (max-width:960.98px){.fresnel-at-tablet{display:none!important;}}\n@media not all and (min-width:961px) and (max-width:1280.98px){.fresnel-at-laptop{display:none!important;}}\n@media not all and (min-width:1281px) and (max-width:1680.98px){.fresnel-at-laptopL{display:none!important;}}\n@media not all and (min-width:1681px) and (max-width:1920.98px){.fresnel-at-laptopLL{display:none!important;}}\n@media not all and (min-width:1921px){.fresnel-at-laptopXL{display:none!important;}}\n@media not all and (max-width:560.98px){.fresnel-lessThan-tablet{display:none!important;}}\n@media not all and (max-width:960.98px){.fresnel-lessThan-laptop{display:none!important;}}\n@media not all and (max-width:1280.98px){.fresnel-lessThan-laptopL{display:none!important;}}\n@media not all and (max-width:1680.98px){.fresnel-lessThan-laptopLL{display:non ...

# %%
soup.find_all('p')[0]
# Out:
# <p class="AppBanner__Caption-sc-f58kks-2 dpipaL">350万人が利用する会社訪問アプリ</p>

# %%
soup.find('p')
# Out:
# <p class="AppBanner__Caption-sc-f58kks-2 dpipaL">350万人が利用する会社訪問アプリ</p>

# %%
soup.p.text
# Out:
# '350万人が利用する会社訪問アプリ'

# %%
soup_class = soup.find_all('span', attrs={'class': 'JobPostSupporterPanel__Message-sc-1hz50ba-1 pRlvy'})

# %%
soup_class[0].text[:2]
# Out:
# '3人'

# %%
login = browser.find_element(By.CLASS_NAME, "cxRWzk")
login.click()

# %%
google_login = browser.find_element(By.CLASS_NAME, 'LoginModalView__IconBase-sc-1rr67fk-9')

# %%
# EdgeDriverのパスを設定
# driver_path = r"C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe"
# Serviceオブジェクトを介してパスを渡す
# svc = Service(executable_path = driver_path)

# Edgeを起動
# driver = webdriver.Edge(service = svc)
# 指定したURLに遷移する
# driver.get("https://www.google.co.jp")
